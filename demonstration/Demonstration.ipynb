# %%
import sys
sys.path.insert(1, "../")

def spaceSplitter(list):
    return list.split(" ")

# %%
from IPython.display import Image
import pickle


from demonstration.feature_loader import get_features_for
from dataset.dataset_map_entry import Gender
from dataset.dataset_map_entry import AgeGroup
from IPython.display import Markdown, display

# %%
def printmd(string):
    display(Markdown(string))

def show_result(gender, age):
    printmd('GENDER : **' + str(Gender(gender)).replace('Gender.', '') + '**')
    printmd('AGE GROUP: **' + str(AgeGroup(age)).replace('AgeGroup._', '').replace('_', '-') + '**')

# %% [markdown]
# ## 0. Load pretrained models

# %%
genderModel = pickle.load(open("gender.pkl", "rb"))
ageModel = pickle.load(open("age.pkl", "rb"))

# %% [markdown]
# ##  Mystery challenger \#1

# %%
Image(filename='mystery_guest_0.png', width=300)

# %%
X = get_features_for('./mystery_guest_0.pkl')
gender = genderModel.predict(X)
age = ageModel.predict(X)
show_result(gender, age)
# Out:
# GENDER : **MALE**
# AGE GROUP: **50-64**

# %% [markdown]
# ##  Mystery challenger \#2

# %%
Image(filename='mystery_guest_1.png', width=300)

# %%
X = get_features_for('./mystery_guest_1.pkl')
gender = genderModel.predict(X)
age = ageModel.predict(X)
show_result(gender, age)
# Out:
# GENDER : **FEMALE**
# AGE GROUP: **25-34**

# %% [markdown]
# ##  Mystery challenger \#3

# %%
Image(filename='mystery_guest_2.png', width=300)

# %%
X = get_features_for('./mystery_guest_2.pkl')
gender = genderModel.predict(X)
age = ageModel.predict(X)
show_result(gender, age)
# Out:
# GENDER : **MALE**
# AGE GROUP: **35-49**

# %% [markdown]
# ##  Mystery challenger \#4

# %%
Image(filename='mystery_guest_3.png', width=300)

# %%
X = get_features_for('./mystery_guest_3.pkl')
gender = genderModel.predict(X)
age = ageModel.predict(X)
show_result(gender, age)
# Out:
# GENDER : **MALE**
# AGE GROUP: **35-49**

# %% [markdown]
# ##  Mystery challenger \#5

# %%
Image(filename='mystery_guest_4.png', width=300)

# %%
X = get_features_for('./mystery_guest_4.pkl')
gender = genderModel.predict(X)
age = ageModel.predict(X)
show_result(gender, age)
# Out:
# GENDER : **MALE**
# AGE GROUP: **35-49**
